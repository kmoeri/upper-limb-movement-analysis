# %%
# libraries
import toml
import numpy as np

# %% [markdown]
# ## 1) Testing File Name Parser

# %%
import src.utils as utils

# config
with open('config.toml') as f:
    config = toml.load(f)

affected_side_lst: list = config['participant_info']['affected_side']
file_path: str = 'home/blabla/SenseUp_P001_ximea_T1_WT-10_camZ.mp4'
print(utils.parse_filename(file_path, affected_side_lst))
# Out:
# ['P001', 'L']
# ('P001', 'T1', 'Unknown', 'Affected', 'L')
